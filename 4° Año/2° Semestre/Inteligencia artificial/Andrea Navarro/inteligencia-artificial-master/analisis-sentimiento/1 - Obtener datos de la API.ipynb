# %% [markdown]
# # Obtener datos de la API

# %% [markdown]
# ## Obtener una cuenta de Twitter Developer
#
# - Crear una cuenta en <a href="https://twitter.com/">Twitter</a> o ingresar a una ya creada
# - Solicitar una <a href="https://developer.twitter.com/en/portal/petition/use-case">cuenta de developer</a>
# <br/>
# <img src="img/twitter_api_1.png" style="width:50%;float:left;border:1px solid black">
# <img src="img/twitter_api_2.png" style="width:50%;float:left;border:1px solid black">
# <img src="img/twitter_api_3.png" style="width:50%;float:left;border:1px solid black">
# <img src="img/twitter_api_4.png" style="width:50%;float:left;border:1px solid black">
#
# #### How will you use the Twitter API or Twitter Data?
#
# I will search and filter tweets with specific hashtags in order to perform data mining and sentiment analysis practices. These tasks are part of the Artificial Intelligence course. The extracted data will not be used for any other purpose.
#
# #### Are you planning to analyze Twitter data?
#
# I will perform sentiment analysis of the content of the tweets and their geographical location. The type of content of each tweet will be evaluated (links, images, videos)
#
#
# <br/><br/>
# <img src="img/twitter_api_5.png" style="width:50%;float:left;border:1px solid black">
# <img src="img/twitter_api_6.png" style="width:50%;float:left;border:1px solid black">
#
#
# ### Responder mail
#
# Si Twitter envía un mail solicitando más información responder con el siguiente mensaje.
#
# <code>
#     I will search and filter tweets with specific hashtags in order to perform data mining and sentiment analysis practices. These tasks are part of the Artificial Intelligence course. The extracted data will not be used for any other purpose.
#     I will perform sentiment analysis of the content of the tweets and their geographical location. The type of content of each tweet will be evaluated (links, images, videos)
#     I will not be using the Tweeting, Retweeting, or liking content. I will only use the API to obtain tweets content.
#     The content of the tweets will not be shown. The content will only be used to carry out data analysis exercises during the course.
# </code>

# %% [markdown]
# ## Crear aplicación
#
# - Crear proyecto
# - Crear aplicación dentro del proyecto
# - Obtener y guardar claves (copiar todas las claves antes de continuar ya que no pueden ser accedidas más adelante)
#
# <br/>
# <img src="img/twitter_api_8.png" style="width:30%;float:left;border:1px solid black">
# <img src="img/twitter_api_7.png" style="width:70%;float:left;border:1px solid black">

# %% [markdown]
# ## Cargar Token en variables de entorno
#
#  - Cargar el valor del token en un archivo .env
#  <code>export 'BEARER_TOKEN'='valor del bearer token' </code>
#  - Agregar el archivo .env dentro del .gitignore en caso de trabajar en repositorio

# %% [markdown]
# ## Cargar valor del Token en la aplicación

# %%
import os
from dotenv import load_dotenv
# Cargar valores del archivo .env en las variables de entorno
load_dotenv()
# Cargar valor del token a variable
bearer_token = os.environ.get("BEARER_TOKEN")

# %% [markdown]
# ## Definir consulta a la API
#
# ### URL de la consulta
#
# Definir la URL de acuerdo a los datos requeridos de acuerdo a la documentación de la <a href="https://developer.twitter.com/en/docs/twitter-api/api-reference-index">API</a>

# %%
url = "https://api.twitter.com/2/tweets/search/recent"

# %% [markdown]
# ## Definir parámetros adicionales
#
# Definr valores como el rango de fecha, hashtag, contenido y campos requeridos.

# %%
params = {
    'query': '#machinelearning -is:retweet',
    'tweet.fields':'created_at',
    'max_results':100
}

# %% [markdown]
# ## Definir cabecera
# La cabecera debe llevar el Token de autenticación para que la consulta sea autorizada

# %%
headers = {
    "Authorization": f"Bearer {bearer_token}",
    "User-Agent":"v2FullArchiveSearchPython"
}

# %% [markdown]
# ## Realizar consulta

# %%
import requests
response = requests.get(url, headers=headers, params=params)
print(response)
# Generar excepción si la respuesta no es exitosa
if response.status_code != 200:
    raise Exception(response.status_code, response.text)
print(response.json())
# Out:
# <Response [200]>
# {'data': [{'created_at': '2021-10-04T14:57:55.000Z', 'id': '1445040491490328579', 'text': 'The latest Great ideas from Good Comms! https://t.co/mkSMskdnsq Thanks to @CynoteckTS #ai #machinelearning'}, {'created_at': '2021-10-04T14:57:54.000Z', 'id': '1445040487094788104', 'text': "Machine learning can pinpoint 'genes of importance' that help crops to grow with less fertilizer, according to a new study. It can also predict additional traits in plants and disease outcomes in animals!\n\n#futurepositive #machinelearning #ml #artificialintelligence #ai #plants https://t.co/7vkY81PJqz"}, {'created_at': '2021-10-04T14:57:26.000Z', 'id': '1445040368429449219', 'text': 'You should read Prof. #ArtificialIntelligence #learning #machinelearning via https://t.co/eBW8Lmmpx7 https://t.co/hIovg91MRW'}, {'created_at': '2021-10-04T14:57:14.000Z', 'id': '1445040318223683586', 'text': '#hclswlobp\xa0#nocode\xa0#lowcode\xa0#javascript\xa0#github\xa0#nodejs\xa0#cybersecurity\xa0#devops\xa0#100DaysOfCode\xa0#datascience\xa0#ai\xa0#bot\xa0#codenewbie\xa0#iot\xa0#machinelearning\xa0#Python\xa0#Serverless\xa0#womenintech #marketing #unica #precisionmarketing #postcovid  https://t.co/LVkzIMQzpd'}, {'created_at': '2021-10-04T14:56:11.000Z', 'id': '1445040054682984452', 'text': 'Most people come face to face with AI technologies primarily in the retail and e-commerce space.\n\nhttps://t.co/quNnTjSHgs\n#Ai #MachineLearning #DeepLearning #DataScience #Fintech #healthcare #marketing #5G #AIrevolution #Technologies'}, {'created_at': '2021-10-04T14:56:05.000Z', 'id': '1445040031597535234', 'text': 'Assignment help hotline\n +1(539)345-5307\n#NodeJs\n#DigitalMarketing\n#cybersecurity\n#AI #DataScience #MachineLearning #BigData #100DaysOfCode #Python\n#DigitalTransformation\n#CodeNewbie\n#WomenWhoCode\n#DeleteFacebook \n#peter obi\n#SHIB\n#assignmentdue \n#Essay \n#HometownChaChaCha https://t.co/ZHR1aImZsF'}, {'created_at': '2021-10-04T14:56:04.000Z', 'id': '1445040024584552454', 'text': 'RT What can go wrong with ML projects? https://t.co/1aQD6NMLs8 #machinelearning #projects #datascience #editorspick #officehours https://t.co/8lU2NtEMuO'}, {'created_at': '2021-10-04T14:56:02.000Z', 'id': '1445040019362746373', 'text': 'The latest The Information technology Daily! https://t.co/n0G82jY0ba #machinelearning #ai'}, {'created_at': '2021-10-04T14:55:45.000Z', 'id': '1445039946545381388', 'text': 'Me applying Deep Learning on literally every problem 😂\n\nWhile you enjoy this hilarious meme, make sure to try different approaches and practice in our ongoing AI challenges.\n\nHead on here to participate: https://t.co/eZUp2fkvRA\n\n~via u/conradws\n\n#datascience #machinelearning https://t.co/2FcD32AJEo'}, {'created_at': '2021-10-04T14:55:31.000Z', 'id': '1445039887653253124', 'text': 'The latest The Social media Daily! https://t.co/F9S6koCtp8 #machinelearning #ai'}, {'created_at': '2021-10-04T14:55:27.000Z', 'id': '1445039872717336577', 'text': '#StyleGAN #MachineLearning #Python https://t.co/fkhls273X8'}, {'created_at': '2021-10-04T14:55:16.000Z', 'id': '1445039823031574530', 'text': '#Infographic: Here you have a great graphic to understand better the differences between human and #artificialintelligence! Via  @antgrasso\n\n #ai #machinelearning #technology #programming #tech #robotics #bigdata #coding #iot #computerscience #innovation #data https://t.co/gyDJZgqXTZ'}, {'created_at': '2021-10-04T14:55:00.000Z', 'id': '1445039756794945539', 'text': 'NEED a JOB?\nSign up now https://t.co/rMErDK45VP\nNO MIDDLEMAN. FREE OF CHARGE\n#Job #JobSearch #work #DataAnalytics #MachineLearning #Python #JavaScript #WomenWhoCode #Programming #Coding #100DaysofCode #DEVCommunity #gamedev #gamedevelopment #indiedev #IndieGameDev #Mobile #gamers https://t.co/oxGj1nKXoo'}, {'created_at': '2021-10-04T14:54:33.000Z', 'id': '1445039644899381248', 'text': 'What can go wrong with ML projects? https://t.co/ZfYCtZ30es #WeWantData #Data #Insights #IoT #Cloud #DataScience #MachineLearning #Innovat ...

# %% [markdown]
# ## Formatear respuesta
#
# Convertir respuesta en un dataframe de Pandas

# %%
import pandas as pd
df = pd.json_normalize(response.json()['data'])
df
# Out:
#                   created_at                   id  \
# 0   2021-10-04T14:57:55.000Z  1445040491490328579
# 1   2021-10-04T14:57:54.000Z  1445040487094788104
# 2   2021-10-04T14:57:26.000Z  1445040368429449219
# 3   2021-10-04T14:57:14.000Z  1445040318223683586
# 4   2021-10-04T14:56:11.000Z  1445040054682984452
# ..                       ...                  ...
# 95  2021-10-04T14:35:01.000Z  1445034728428507147
# 96  2021-10-04T14:34:55.000Z  1445034702243569668
# 97  2021-10-04T14:34:44.000Z  1445034656542478347
# 98  2021-10-04T14:34:41.000Z  1445034643032510465
# 99  2021-10-04T14:34:20.000Z  1445034557619810304
#
#                                                  text
# 0   The latest Great ideas from Good Comms! https:...
# 1   Machine learning can pinpoint 'genes of import...
# 2   You should read Prof. #ArtificialIntelligence ...
# 3   #hclswlobp #nocode #lowcode #javascript #githu...
# 4   Most people come face to face with AI technolo...
# ..                                                ...
# 95  Top Machine Learning Projects  Beginners Must ...
# 96  The latest The Frieling-Bailey Daily! https://...
# 97  The latest The Education Daily! https://t.co/Z...
# 98  The latest The c&amp;c Daily! https://t.co/Cmr...
# 99  #IoT in Agriculture: https://t.co/PSsiTdm9up\n...
#
# [100 rows x 3 columns]

# %% [markdown]
# # Ejercicios
#
#  A partir de la documentación del endpoint <a href="https://developer.twitter.com/en/docs/twitter-api/tweets/search/api-reference/get-tweets-search-recent"> Recent </a> y las opciones de <a href="https://developer.twitter.com/en/docs/twitter-api/tweets/search/integrate/build-a-query"> query </a> obtener:
#
#  - Una lista de las fechas y creación de los tweets realizados por el usuario @kdnuggets que contenga el hashtag #NLP

# %%
user='@kdnuggets'
hashtag='#NLP'
params = {
    'query': f'{user} {hashtag} -is:retweet',
    'tweet.fields':'created_at',
    'max_results':100
}
response = requests.get(url, headers=headers, params=params)
print(response)
# Generar excepción si la respuesta no es exitosa
if response.status_code != 200:
    raise Exception(response.status_code, response.text)
df = pd.json_normalize(response.json()['data'])
df
# Out:
# <Response [200]>
#                  created_at                   id  \
# 0  2021-09-26T15:37:38.000Z  1442151386163003396
# 1  2021-09-26T13:45:04.000Z  1442123056613249033
# 2  2021-09-25T11:46:43.000Z  1441730882310586375
# 3  2021-09-24T10:56:47.000Z  1441355928792551425
#
#                                                 text
# 0  Understanding the day-to-day applications of #...
# 1  Understanding the day-to-day applications of #...
# 2  Relax! #DataScientists will not go extinct in ...
# 3  Are Larger Language Models Less Truthful?\n\n#...

# %% [markdown]
# - Una lista de los textos y nombres de usuario correspondientes a los tweets que contengan los hashtags #NLP y #MachineLearning que no sean retweets

# %%
hashtag='#NLP #MachineLearning'
params = {
    'query': f'{hashtag} -is:retweet',
    'user.fields': 'username',
    'expansions': 'author_id',
    'max_results': 100
}
response = requests.get(url, headers=headers, params=params)
# Generar excepción si la respuesta no es exitosa
if response.status_code != 200:
    raise Exception(response.status_code, response.text)
df_tweets = pd.json_normalize(response.json()['data'])
authors = pd.json_normalize(response.json()['includes']['users'])
authors
# Out:
#                      id                                      name  \
# 0   1403861754808049666  د. خلود صالح المانع | Dr. Khulood Almani
# 1             467513287                           Iain Brown, PhD
# 2   1029341716883492864                       TechTalk™ Boulevard
# 3   1346747196452925442                             Sakib Hossain
# 4   1083699084760895496                                   Nikseam
# 5            1264433760                            Elitsa Krumova
# 6    918112383628963841                                David Sobo
# 7   1435645100051206154                               Neil Esparz
# 8   1269107130776223745                                Grepnetics
# 9   1442886288927981570                                Tony Edwin
# 10   727247361722851328                            Sandeep Sharma
# 11            291831562                             Paula Piccard
# 12           1954706040                             Nicolas Pinto
# 13  1053697748321501184                                    PINAKI
# 14  1426407466405822465                             Justine Booth
# 15            369515982                        Shahul Hameed.M 🇮🇳
# 16   752910638192660482                                  Virtuoso
# 17            836510570                          Giuliano Liguori
# 18            181221694                              Vivek Dahiya
# 19  1019916306160799745                                  Automeme
# 20  1400418183052283911                                 Indika AI
# 21  1399707627597279236                               Businessbea
# 22           2477954400                                   raja007
# 23  1021322525287026688                          Machine Learning
# 24  1031495988857499648                                Blockchain
# 25  1262088816237645824                              TrendingNews
# 26  1418280964959178755              Cynthy Assignments•Exams✍️✍️
# 27           1643123766                                     Umair
# 28  1017816919980769280                                 Ravi Dugh
# 29  1124240303055966208                               GenieTalkAI
# 30   840922607654445058                               DataWorkout
# 31             49427323                        Richard Eudes, PhD
# 32  1444967661851471875                             Aparna Mishra
# 33             21967062                              John Felix ✨
# 34            268619848                          Syeda Sheraj Ali
# 35  1430804322351304708               Digital Edwin #DigitalEdwin
#
#            username
# 0    Khulood_Almani
# 1       IainLJBrown
# 2      TechTalkBlvd
# 3         sakib8783
# 4          NikseamC
# 5       Eli_Krumova
# 6      DS_Analytics
# 7        EsparzNeil
# 8        Grepnetics
# 9   TonyEdw68907630
# 10    its_sandeep11
# 11    Paula_Piccard
# 12    Nicolas2Pinto
# 13     PinakiLaskar
# 14   JustineBooth20
# 15        sh_hameed
# 16      Virtuoso_QA
# 17       ingliguori
# 18         MeharVik
# 19         automeme
# 20        Indika_AI
# 21      businessbea
# 22        raja00710
# 23  machinelearnTec
# 24   Blockchain_exp
# 25   TrendingNews_7
# 26     CynthyEssays
# 27    akbarth3great
# 28         ravidugh
# 29      GenieTalkAI
# 30      dataworkout
# 31     RichardEudes
# 32  AparnaMishra144
# 33    JohnnieFellix
# 34         Sheraj99
# 35     DigitalEdwyn

# %%
list = []
for index, row in df_tweets.iterrows():
    author = authors.loc[authors['id'] == row['author_id']].username.item()
    text = row['text']
    list.append({'author': author, 'text': text})
print(list)
# Out:
# [{'author': 'Khulood_Almani', 'text': '🚘#ElectricVehicles set to triple in 2021\n\n#EV #SmartCities #Technology #innovation #Python\n#DigitalMarketing #Industry40 #ArtificialIntelligence #MachineLearning #CyberSecurity #DataScience #bot #coding  #NodeJS #NLP #javascript #django #TensorFlow #devops #100DaysOfCode #RHOBH https://t.co/Dngv9qFTZY'}, {'author': 'IainLJBrown', 'text': 'Learn tips on how to break the cycle of bias in AI decision making to build a better place for humanity. #WomenInAnalytics #ArtificialIntelligence #AI #DataScience #100DaysOfCode #Python #MachineLearning #BigData #DeepLearning #NLP #Robots #IoT https://t.co/kU8x5Qz2ye'}, {'author': 'TechTalkBlvd', 'text': 'Should you fear #MachineLearning\n\n#DigitalTransformation #DeepLearning\n#programming #Database #AI #coding #DataScientists #Analytics #BigData #Rstats #AI #Reactjs #Python #DataScience #Tech #IIoT #ML #NLP #javascript #TensorFlow #DEVCommunity #Serverless #100DaysOfCode #Dataviz https://t.co/r02I1SIiPq'}, {'author': 'sakib8783', 'text': "Hi,\nI'm a #logodesign Expert if you need a logo design please DM me here:https://t.co/2JBMxLZNEd\n\n#programming #Database #Data #Analytics #BigData  #AI #Python #DataScience #tech #IoT #ML #NLP #TensorFlow #Coding #Serverless #100DaysOfCode #dataviz #MachineLearning #DevOps https://t.co/RZ9PQK1pZz"}, {'author': 'NikseamC', 'text': 'One stop Business Solution @ Nikseam\n#FrontEndDeveloper #DEVCommunity\n#cybersecurity #ArtificialIntelligence #DataScience #MachineLearning #BigData #100DaysOfCode #Python #DeepLearning #NLP #nikseam #Robots #IoT #mumbai #DevOps #5G #DigitalTransformation #WomenWhoCode #Startup https://t.co/uJ5wOGfr3v'}, {'author': 'NikseamC', 'text': 'One stop Business Solution @ Nikseam\n#FrontEndDeveloper #DEVCommunity\n#cybersecurity #ArtificialIntelligence #DataScience #MachineLearning #BigData #100DaysOfCode #Python #DeepLearning #NLP #nikseam #Robots #IoT #mumbai #DevOps #5G #DigitalTransformation #WomenWhoCode #Startup https://t.co/WHGAqS1ME8'}, {'author': 'IainLJBrown', 'text': 'Artificial Intelligence at Airbnb – Two Unique Use-Cases - Emerj\n\nRead more here: https://t.co/eGxJt0GChc\n\n#ArtificialIntelligence #AI #DataScience #100DaysOfCode #Python #MachineLearning #BigData #DeepLearning #NLP #Robots #IoT'}, {'author': 'Eli_Krumova', 'text': 'Evolution of Hybrid #MultiCloud\n👉🏽https://t.co/8ZGBph46Xb\nv/ @Analytics_699\n\n#datamining #DataScience #Analytics #BigData #AI #MachineLearning #ML #IoT #IIoT #IoTPL #Python #Serverless #RPA #NLP #Cloud #CloudComputing #Robotics #SelfDrivingCars #coding #programming #100DaysOfCode https://t.co/NX5cUBohde https://t.co/tuUnxBzjzc'}, {'author': 'Khulood_Almani', 'text': 'Top🔟Recent #Chatbots to Make Note of in 2021\n\n👉https://t.co/JPlOFSynAq\n\n#ArtificialIntelligence #MachineLearning #Python\n#CyberSecurity #DataScience #innovation #Tech #Industry40 #DigitalMarketing #bot #coding #devops #NodeJS #NLP #javascript #django #TensorFlow #100DaysOfCode https://t.co/E4kgj2bYsb'}, {'author': 'Eli_Krumova', 'text': 'Leading Type of #IoT #Wireless #Technologies\nhttps://t.co/0AXmSsB75o\nv @Analytics_699\n\n#DataScience #Analytics #BigData #AI #MachineLearning #ML #IIoT #IoTPL #Python #Rstats #Cloud #CloudComputing #SmartCities #SmartHome #Robotics #RPA #5G #mHealth #NLP #Serverless #100DaysOfCode https://t.co/u8JIETQFQP https://t.co/7UCRJhPwcc'}, {'author': 'DS_Analytics', 'text': 'Hannover Re to invest over £5 million in underwriting initiative - Insurance Business https://t.co/B9kSWnjf22\n\n#DataScience #MachineLearning #DeepLearning #Insurance #NLP #Robots #AI #IoT #BigData'}, {'author': 'DS_Analytics', 'text': 'Cloverleaf Analytics Makes BI More Accessible for Insurers - MarTech Series https://t.co/X5kY4IHGcE\n\n#DataScience #MachineLearning #DeepLearning #Insurance #NLP #Robots #AI #IoT #BigData'}, {'author': 'DS_Analytics', 'text': 'Verisk AI Leverages Yelp Data to Help Insurers Underwrite Small Commercial Risk - Insurance News Net https://t.co/Ruj6EB9I ...

# %% [markdown]
# - Una lista de los textos y enlaces de los tweets que contengan los hashtags #InteligenciaArtificial o #IA en español

# %%
hashtag='#InteligenciaArtificial OR #IA'
params = {
    'query': f'{hashtag} -is:retweet lang:es',
    'user.fields': 'username',
    'expansions': 'author_id',
    'max_results': 100
}
response = requests.get(url, headers=headers, params=params)
# Generar excepción si la respuesta no es exitosa
if response.status_code != 200:
    raise Exception(response.status_code, response.text)
df_tweets = pd.json_normalize(response.json()['data'])
authors = pd.json_normalize(response.json()['includes']['users'])
authors
# Out:
#                      id                         name         username
# 0    751352816762023936              Big Data Campus    campusbigdata
# 1             110380312               Plain Concepts    plainconcepts
# 2   1100696023528292354                AllianzGI_ESP    AllianzGI_Esp
# 3             205640203  Telefónica Grandes Empresas   TE_GranEmpresa
# 4             562466814            Rigoberto J Nodal  nodalrigobertoj
# ..                  ...                          ...              ...
# 82           1218902551                Carlos Quenan    CarlosAQuenan
# 83             62426117                  Julio Cesar    CesarRuizRuiz
# 84            275179722               Tania Martagón    TaniaMartagon
# 85            372460779                     IFEX ALC          IFEXALC
# 86            294071256                         IFEX             IFEX
#
# [87 rows x 3 columns]

# %%
list = []
for index, row in df_tweets.iterrows():
    author = authors.loc[authors['id'] == row['author_id']].username.item()
    tid = row['id']
    text = row['text']
    list.append({'url': f'https://twitter.com/{author}/status/{tid}', 'text': text})
print(list)
# Out:
# [{'url': 'https://twitter.com/campusbigdata/status/1445056829772476417', 'text': 'RT @InnovaCuenta: Datos Personales e Inteligencia Artificial🤖 \nGuillermo Cernuda, Director de Operaciones en DoGood y tutor del Máster en B…'}, {'url': 'https://twitter.com/plainconcepts/status/1445056815402782721', 'text': 'Gracias a nuestra solución Smart Concepts, @tecnalia ha conseguido la digitalización de sus laboratorios y además la aceleración de los procesos de #innovacion  y comunicación.\n\n#IoT #CloudComputing #IA #Industria40\n\n¿Quieres descubrir más?\nhttps://t.co/PkR0hfGDHa'}, {'url': 'https://twitter.com/AllianzGI_Esp/status/1445056153256402954', 'text': 'Perspectivas de la #inteligenciaartificial para 2021\n\nComo inversores, nos centramos en identificar empresas que potencien la IA para generar resultados que beneficien a todas sus partes interesadas. \n\nhttps://t.co/xWyx2yFOJr https://t.co/mQAYocCafQ'}, {'url': 'https://twitter.com/TE_GranEmpresa/status/1445056115335524358', 'text': 'Se prevé que los proyectos de #digitalización de las ciudades crezcan de manera exponencial tras el COVID\n\n➡️ Principales tecnologías habilitadoras de las #smartcities: IoT, #bigdata, #IA, #5G y #cloud \n\n@mertrak 👉 https://t.co/KZs8rI4ltp'}, {'url': 'https://twitter.com/nodalrigobertoj/status/1445055609791909889', 'text': 'RT @UNESCO_es: ¿Sabías que solo el 6% de los desarrolladores profesionales de software y el 12% de los investigadores de #InteligenciaArtif…'}, {'url': 'https://twitter.com/rodriguezhernan/status/1445055319692951555', 'text': '🌾 @Cajamar e @IBM_ES ponen la #inteligenciaartificial al servicio de los agricultores y la industria agroalimentaria españoles.\n\n#PlataformaTierra lanza servicios pioneros que permitirán calcular el riego y la fertilización óptimos.\n\nhttps://t.co/i6i8NLDyDY https://t.co/TQxn94KO1v'}, {'url': 'https://twitter.com/FracttalApp/status/1445054853030555650', 'text': '🔜 ¡No te lo pierdas! \n🗓️Este 14 de Octubre a las 18h CET. \n📌 Inscríbete aquí: https://t.co/sYXDrk6myl\n\n#IoT #GMAO #IA #ML #Fracttal #BarbaraTalks #Webinar https://t.co/LxCdWKpyPx'}, {'url': 'https://twitter.com/jorgeramos7773/status/1445054744460812291', 'text': 'RT @r2rorobles: #AHORA Los 10 principios para #InteligenciaArtificial de la @OECD promueven la innovación y confianza en el desarrollo de l…'}, {'url': 'https://twitter.com/Marissa_mar/status/1445054549753045015', 'text': 'RT @cershi_unesco: #EnVivo\n\nSigue la transmisión de nuestro #CursoEnLínea: “#InteligenciaArtificial y transformación digital para la #segur…'}, {'url': 'https://twitter.com/SERAM_RX/status/1445054180163563525', 'text': 'Hoy comienza el Postgrado en Postprocesado de la imagen médica: #Impresión3D e #InteligenciaArtificial \n\n👉🏾 Una nueva edición en la Universidad Politécnica de Barcelona avalada científicamente por SERAM\n\nMás info ▶️  https://t.co/pZ4Br3GQDw\n\n@la_upc https://t.co/6oQG2g4xMX'}, {'url': 'https://twitter.com/solecamus/status/1445053900646662151', 'text': 'Nuevo episodio de #EstoEsLoQueAI \nHablamos de #ética e #IA. ¿Puede la IA comportarse con ética? ¿Se puede programar la ética? ¿Estamos dispuestos a dejar espacio a los robots en cuestiones que plantean dilemas éticos?\n #podcast https://t.co/NTzPsyl3Ka https://t.co/AVnRZfLT2E'}, {'url': 'https://twitter.com/PequeninWarrior/status/1445052167543472132', 'text': 'RT @campusbigdata: Salidas profesionales de los Expertos en MACHINE LEARNING 😃 \nEl Machine Learning https://t.co/Tbzb1u1jqI aplicada a la #…'}, {'url': 'https://twitter.com/PequeninWarrior/status/1445052147230519301', 'text': 'RT @Merca20: La Inteligencia Artificial tiene la capacidad para realizar un análisis profundo e impulsar las estrategias de marketing. ¿Cóm…'}, {'url': 'https://twitter.com/tromboinfo/status/1445050546281492488', 'text': 'Los últimos avances sobre #trombosis, #emboliapulmonar, su relación con el #cáncer, los tratamientos o la #InteligenciaArtificial serán algunos de los temas de la  1ª Reunión Multidiscipli ...

# %% [markdown]
# ## Descargar a CSV

# %%
df.to_csv('tweets_ej.csv')
