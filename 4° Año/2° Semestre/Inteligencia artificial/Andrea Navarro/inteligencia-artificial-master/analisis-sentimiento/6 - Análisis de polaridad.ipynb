# %% [markdown]
# # Análisis de Polaridad
#
# En análisis de polaridad consiste en otorgar un valor numérico (positivo o negativo) a diferentes palabras o expresiones asociadas a su uso más común con respecto a las emociones.
#
# ### Vader Sentiment Analysis
# VADER Sentiment Analysis es una herramienta de analisis de sentimiento basada en <b>reglas léxicas</b>. Funciona a partir de un conjunto de palabras o <b>lexicón</b> cuyo significado semántico está asociado mayormente a expresiones positivas o negativas. Al analizar una oración Vader tiene en cuenta todas las palabras que puedan afectar el sentimiento expresado y da como resultado un analisis del porcentaje estimado de expresiones positivas y negativas.
#
# Las palabras reconocidas por Vader tienen asociadas un <b>valor numérico</b> positivo o negativo dependiendo de la emoción que expresan. Si una palabra no se encuentra en la lista de palabras valoradas esta no se tiene en cuenta para la evaluación.
#
# Al realizar un análisis de sentimiento sobre un texto Vader devuelve 4 valores
# - Porcentaje del contenido que cae dentro de la clasificación positiva
# - Porcentaje del contenido que cae dentro de la clasificación neutral
# - Porcentaje del contenido que cae dentro de la clasificación negativa
# - Puntuación compuesta: Total de los valores obtenidos normalizado entre 1 y -1

# %%
import nltk
nltk.download('vader_lexicon')
#conda install -c conda-forge vadersentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/lucas/nltk_data...

# %% [markdown]
# ### Obtener polaridad

# %%
sentence = "This is a great product! Very good quality"
# Instanciar Analizador
sentiment_analyzer = SentimentIntensityAnalyzer()
# Analizar polaridad de la oración
analisis = sentiment_analyzer.polarity_scores(sentence)
print(analisis)
# Out:
# {'neg': 0.0, 'neu': 0.442, 'pos': 0.558, 'compound': 0.8217}

# %% [markdown]
# ## Ejemplo

# %%
import pandas as pd
df = pd.read_csv("movie-reviews.csv")
df
# Out:
#                                              reviews
# 0  Excellent movie. The acting was great and it i...
# 1               A bit boring at first but enjoyable.
# 2    Very boring. You cant tell it has a low budget.
# 3                I loved it! Best movie of the year!
# 4  The special effects looked cheap and the plot ...
# 5  The actors did a good job but the script is te...
# 6                                Boring. So boring.
# 7                     Not the worst movie I've seen
# 8                                   A waste of time

# %%
df["negative"] = ""
df["neutral"] = ""
df["positive"] = ""
df["result"] = ""
for index, row in df.iterrows():
    #Analizar cada review
    analisis = sentiment_analyzer.polarity_scores(row['reviews'])
    row["negative"] = analisis["neg"]
    row["neutral"] = analisis["neu"]
    row["positive"] = analisis["pos"]
    # Evaluar que valores se considerarán positivo o negativo
    if analisis['compound'] > 0.6 :
        row["result"] = "Positive"
    elif analisis['compound'] <  0.6:
        row["result"] = "Negative"
    else :
        row["result"] = "Neutral"
df
# Out:
#                                              reviews negative neutral  \
# 0  Excellent movie. The acting was great and it i...      0.0   0.469
# 1               A bit boring at first but enjoyable.    0.157   0.476
# 2    Very boring. You cant tell it has a low budget.     0.37    0.63
# 3                I loved it! Best movie of the year!      0.0   0.409
# 4  The special effects looked cheap and the plot ...      0.0   0.803
# 5  The actors did a good job but the script is te...    0.275   0.596
# 6                                Boring. So boring.      0.83    0.17
# 7                     Not the worst movie I've seen       0.0   0.603
# 8                                   A waste of time     0.483   0.517
#
#   positive    result
# 0    0.531  Positive
# 1    0.367  Negative
# 2      0.0  Negative
# 3    0.591  Positive
# 4    0.197  Negative
# 5    0.129  Negative
# 6      0.0  Negative
# 7    0.397  Negative
# 8      0.0  Negative

# %% [markdown]
# # Ejercicio
#
# - Obtener de la API Tweets que no sean retweet y que contengan el hashtag #SpiderMan2 en inglés.
# - Realizar limpieza en los datos
# - Evaluar la polaridad

# %%
import os
from dotenv import load_dotenv
import pandas as pd
import requests
# Cargar valores del archivo .env en las variables de entorno
load_dotenv()
# Cargar valor del token a variable
bearer_token = os.environ.get("BEARER_TOKEN")
url = "https://api.twitter.com/2/tweets/search/recent"
headers = {
    "Authorization": f"Bearer {bearer_token}",
    "User-Agent":"v2FullArchiveSearchPython"
} 
hashtag='#SpiderMan2'
params = {
    'query': f'{hashtag} -is:retweet lang:en',
    'max_results':100
}
response = requests.get(url, headers=headers, params=params)
# Generar excepción si la respuesta no es exitosa
if response.status_code != 200:
    raise Exception(response.status_code, response.text)
json_response = response.json()['data']
df = pd.json_normalize(json_response)
df
# Out:
#                      id                                               text
# 0   1450253980819496961  Happy birthday, @NajJeter. I can't wait for yo...
# 1   1450231450872262667  Day 37 of asking Insomniac to please add the C...
# 2   1450176713380573184  @NetflixUK @netflix where is #spiderman2?? How...
# 3   1450120733972119552  @RaggySays hello Jason how are you today I wan...
# 4   1450120372527960068  @AdamNoonchester hello Adam how are you today ...
# ..                  ...                                                ...
# 95  1448125476749332488  @insomniacgames \nI have one important questio...
# 96  1448125117494607879  “Let me slip away!!!” 🔥🔥🔥 #SpiderMan2 #Quarant...
# 97  1448123375218462731  @ToastDraws @PhaseZeroCB thanks for hanging. t...
# 98  1448123153406906368  Allways good to see you Normie #avengeme #Spid...
# 99  1448123129692360712  Epic night of #SpiderMan2! \n\nWe're watching ...
#
# [100 rows x 2 columns]

# %%
import nltk
from nltk.corpus import stopwords
# nltk.download('stopwords')
print(stopwords.words('english'))
stop_words = set(stopwords.words('english'))
import re
from nltk.tokenize import TweetTokenizer
# Instanciar Tokenizer
tt = TweetTokenizer()
# Aplicar Tokenizer a la columna
tokenized_text = df['text'].apply(tt.tokenize)
def clean(x):
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)
    n = regrex_pattern.sub(r'', x)
    if (not x.lower() in stop_words) and (x[0] != '@') and (n != '') and (x[0] != '#'):
        return True
    else:
        return False
for index, tweet in enumerate(tokenized_text):
    tweet = [x for x in tweet if clean(x)]
    tokenized_text[index] = tweet
df["tokenized_text"] = tokenized_text
df
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
#                      id                                               text  \
# 0   1450253980819496961  Happy birthday, @NajJeter. I can't wait for yo...
# 1   1450231450872262667  Day 37 of asking Insomniac to please add the C...
# 2   1450176713380573184  @NetflixUK @netflix where is #spiderman2?? How...
# 3   1450120733972119552  @RaggySays hello Jason how are you today I wan...
# 4   1450120372527960068  @AdamNoonchester hello Adam how are you today ...
# ..                  ...                                                ...
# 95  1448125476749332488  @insomniacgames \nI have one important questio...
# 96  1448125117494607879  “Let me slip away!!!” 🔥🔥🔥 #SpiderMan2 #Quarant...
# 97  1448123375218462731  @ToastDraws @PhaseZeroCB thanks for hanging. t...
# 98  1448123153406906368  Allways good to see you Normie #avengeme #Spid...
# 99  1448123129692360712  Epic night of #SpiderMan2! \n\nWe're watching ...
#
#                                        tokenized_text  \
# 0   [Happy, birthday, ,, ., can't, wait, return, M...
# 1   [Day, 37, asking, Insomniac, please, add, Capt...
# 2                  [?, ?, could, leave, ?, Preparing]
# 3   [hello, Jason, today, want, present, new, suit...
# 4   [hello, Adam, today, want, present, new, suit,...
# ..                                                ...
# 95  [one, important, question, ., know, said, woul...
# 96  [“, Let, slip, away, !, !, !, ”, https://t.co/...
# 97       [thanks, hanging, ., fun, ., love, movie, .]
# 98  [Allways, good, see, Normie, https://t.co/3yB4...
# 99  [Epic, night, !, We're, watching, October, 26,...
#
#                                             polaridad negative neutral  \
# 0   Happy birthday , . can't wait return Miles #Sp...      0.0   0.802
# 1   Day 37 asking Insomniac please add Captain Uni...      0.0   0.881
# 2   #spiderman2 ? ? could leave ? Preparing #Spide...    0.179   0.821
# 3   hello Jason today want present new suit Peter ...      0.0   0.767
# 4   hello Adam today want present new suit Peter P...      0.0   0.789
# ..                                                ...      ...     ...
# 95  one important question . know said #Spiderman2...      0.0   0.661
# 96  “ Let slip away ! ! ! ” #SpiderMan2 #Quarantin...      0.0     1.0
# 97  thanks hanging . fun . love movie . #SpiderMan...      0.0   0.402
# 98  Allways good see Normie #avengeme #SpiderManNo...      0.0   0.734
# 99  Epic night #SpiderMan2 ! We're watching #Spide...      0.0     1.0
#
#    positive    result
# 0     0.198   Neutral
# 1     0.119   Neutral
# 2       0.0  Negative
# 3     0.233  Positive
# 4     0.211  Positive
# ..      ...       ...
# 95    0.339  Positive
# 96      0.0  Negative
# 97    0.598  Positive
# 98    0.266   Neutral
# 99      0.0  Negative
#
# [100 rows x 8 columns]

# %%
l = []
for i in df["tokenized_text"]:
    l.append(" ".join(i))
df["polaridad"] = l
df
# Out:
#                      id                                               text  \
# 0   1450253980819496961  Happy birthday, @NajJeter. I can't wait for yo...
# 1   1450231450872262667  Day 37 of asking Insomniac to please add the C...
# 2   1450176713380573184  @NetflixUK @netflix where is #spiderman2?? How...
# 3   1450120733972119552  @RaggySays hello Jason how are you today I wan...
# 4   1450120372527960068  @AdamNoonchester hello Adam how are you today ...
# ..                  ...                                                ...
# 95  1448125476749332488  @insomniacgames \nI have one important questio...
# 96  1448125117494607879  “Let me slip away!!!” 🔥🔥🔥 #SpiderMan2 #Quarant...
# 97  1448123375218462731  @ToastDraws @PhaseZeroCB thanks for hanging. t...
# 98  1448123153406906368  Allways good to see you Normie #avengeme #Spid...
# 99  1448123129692360712  Epic night of #SpiderMan2! \n\nWe're watching ...
#
#                                        tokenized_text  \
# 0   [Happy, birthday, ,, ., can't, wait, return, M...
# 1   [Day, 37, asking, Insomniac, please, add, Capt...
# 2                  [?, ?, could, leave, ?, Preparing]
# 3   [hello, Jason, today, want, present, new, suit...
# 4   [hello, Adam, today, want, present, new, suit,...
# ..                                                ...
# 95  [one, important, question, ., know, said, woul...
# 96  [“, Let, slip, away, !, !, !, ”, https://t.co/...
# 97       [thanks, hanging, ., fun, ., love, movie, .]
# 98  [Allways, good, see, Normie, https://t.co/3yB4...
# 99  [Epic, night, !, We're, watching, October, 26,...
#
#                                             polaridad negative neutral  \
# 0   Happy birthday , . can't wait return Miles PS5...      0.0   0.802
# 1   Day 37 asking Insomniac please add Captain Uni...      0.0   0.881
# 2                         ? ? could leave ? Preparing    0.179   0.821
# 3   hello Jason today want present new suit Peter ...      0.0   0.767
# 4   hello Adam today want present new suit Peter P...      0.0   0.789
# ..                                                ...      ...     ...
# 95  one important question . know said would dark ...      0.0   0.661
# 96    “ Let slip away ! ! ! ” https://t.co/V3yxiBwsAK      0.0     1.0
# 97                thanks hanging . fun . love movie .      0.0   0.402
# 98    Allways good see Normie https://t.co/3yB4fNOv2Y      0.0   0.734
# 99  Epic night ! We're watching October 26 ! Two w...      0.0     1.0
#
#    positive    result
# 0     0.198   Neutral
# 1     0.119   Neutral
# 2       0.0  Negative
# 3     0.233  Positive
# 4     0.211  Positive
# ..      ...       ...
# 95    0.339  Positive
# 96      0.0  Negative
# 97    0.598  Positive
# 98    0.266   Neutral
# 99      0.0  Negative
#
# [100 rows x 8 columns]

# %%
df["negative"] = ""
df["neutral"] = ""
df["positive"] = ""
df["result"] = ""
for index, row in df.iterrows():
    #Analizar cada review
    analisis = sentiment_analyzer.polarity_scores(row['polaridad'])
    row["negative"] = analisis["neg"]
    row["neutral"] = analisis["neu"]
    row["positive"] = analisis["pos"]
    # Evaluar que valores se considerarán positivo o negativo
    if analisis['compound'] > 0.4 :
        row["result"] = "Positive"
    elif analisis['compound'] <  -0.2:
        row["result"] = "Negative"
    else :
        row["result"] = "Neutral"
df[["text", "result"]]
# Out:
#                                                  text    result
# 0   Happy birthday, @NajJeter. I can't wait for yo...  Positive
# 1   Day 37 of asking Insomniac to please add the C...   Neutral
# 2   @NetflixUK @netflix where is #spiderman2?? How...   Neutral
# 3   @RaggySays hello Jason how are you today I wan...  Positive
# 4   @AdamNoonchester hello Adam how are you today ...  Positive
# ..                                                ...       ...
# 95  @insomniacgames \nI have one important questio...  Positive
# 96  “Let me slip away!!!” 🔥🔥🔥 #SpiderMan2 #Quarant...   Neutral
# 97  @ToastDraws @PhaseZeroCB thanks for hanging. t...  Positive
# 98  Allways good to see you Normie #avengeme #Spid...  Positive
# 99  Epic night of #SpiderMan2! \n\nWe're watching ...   Neutral
#
# [100 rows x 2 columns]

# %%
df.to_csv('SpiderMan.csv')

# %%
import csv
with open('SpiderMan.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        print(row['polaridad'], "----", row['result'])
# Out:
# Happy birthday , . can't wait return Miles PS5 . - Giovanni De La Cruz ---- Positive
# Day 37 asking Insomniac please add Captain Universe suit Spider-Man 2 either Peter Miles https://t.co/FlgmlqE6f2 ---- Neutral
# ? ? could leave ? Preparing ---- Neutral
# hello Jason today want present new suit Peter Parker fusion spidey CAP hope like approve 2023 ️ ️ ️ ️ ️ https://t.co/3pESDyz5Lk ---- Positive
# hello Adam today want present new suit Peter Parker fusion spidey CAP hope like approve 2023 ️ ️ ️ ️ ️ ️ ️ ️ https://t.co/kmjOizrl5C ---- Positive
# hello ryan today want present new suit Peter Parker fusion spidey CAP hope like approve 2023 ️ ️ ️ ️ ️ https://t.co/Cx5BtIKH3M ---- Positive
# forget games . https://t.co/6m6XKiqvGk ---- Negative
# Day 36 asking Insomniac please add Captain Universe suit Spider-Man 2 either Peter Miles https://t.co/BJ51Xs5Jmk ---- Neutral
# Found Symbiote Suit leaks . :P , https://t.co/wL1Z9GjJzs ---- Positive
# OMG ! ! Ready https://t.co/hKStmeSLrT ---- Positive
# Spiderman 2 Leak ! ? ! ? ! ? ! https://t.co/WODNdES76D ---- Negative
# Marvel's Spider-Man 2 ( 2023 ) Game Trailer PS5 HD https://t.co/KhobYe9UYk ---- Neutral
# hello jonathan today want present new suit Peter Parker fusion spidey CAP hope like approve ️ ️ ️ ️ https://t.co/91WiX5KcPc ---- Positive
# Game coming excite : ---- Positive
# ’ wait ! ! Plus game trailer makes sense … ! ---- Neutral
# New shows Tom Holland ’ Peter Parker getting run train Alfred Molinas Doc Ock fought Tobey Maguire ’ Peter Parker https://t.co/lMvHdJ48bl ---- Negative
# ’ Yuri Lowenthal chats fan love video game trailer Tony Todd : https://t.co/2iHKPPZGBs ---- Positive
# wish playable character . https://t.co/hApcyFFtdK ---- Positive
# Day 35 asking Insomniac please add Captain Universe suit Spider-Man 2 either Peter Miles https://t.co/G9vLaDEu6q ---- Neutral
# Spider-Man 2 ( 2004 ) - Read 1,036 Movie Reviews Link : https://t.co/FrEpkPFFw0 ---- Neutral
# Best hero shots always sunset https://t.co/N27YJpf9Xs ---- Positive
# hello gavin today want present new suit Peter Parker fusion spidey CAP hope like approve ️ ️ ️ ️ https://t.co/sMTerig8N7 ---- Positive
# hello tommy today want present new suit Peter Parker fusion spidey CAP hope like approve https://t.co/MpDQv563Hq ---- Positive
# friendly neighbor ready join fun Book avail 10 % discount : https://t.co/Al2hhE1fOx https://t.co/uYE6aiO0Rk ---- Positive
# Star Talks Working Fan Response Trailer ( Exclusive ) https://t.co/jvQ2aN4KtQ https://t.co/JsyZVBshLs ---- Positive
# Movie Marathon Review : Spider-Man 2 . https://t.co/lVJjvNRV4Q ---- Neutral
# hello lauren today want present new suit Peter Parker fusion spidey CAP hope like approve Spiderman 2 2023 ️ ️ ️ ️ https://t.co/5p3KsKYt1V ---- Positive
# hello today want present new suit Peter Parker fusion spidey CAP hope like approve insomniac games Spiderman 2 2023 ️ ️ ️ ️ https://t.co/gfzr13QpOa ---- Positive
# Day 34 asking Insomniac please add Captain Universe suit Spider-Man 2 either Peter Miles https://t.co/aEYebD0qwD ---- Neutral
# please make Agent Venom skin Spider-Man 2 ! PLEEEAAAAASE 🥺 🥺 🥺 https://t.co/cH5MRtsxuQ ---- Neutral
# Sub & awesome Shows , incl ( / W / F 12pmET / 9amPT ) & Review show ! REWATCH : ( 2004 ); & deep dive things movie ! https://t.co/hhT0Nc85wC https://t.co/NGlxupMc6d ---- Positive
# Sub & awesome Shows , incl ( / W / F 12pmET / 9amPT ) & Review show ! REWATCH series & dive deep ( ' 04 ) & link https://t.co/hhT0Nc85wC https://t.co/mG6rY0TxD7 ---- Positive
# co-op ? ? talk much latest ! https://t.co/pglvruHFsu ---- Neutral
# Marvel Friday : Way Home ( Spider-Man 2 ) https://t.co/PZoeg0hB9o ---- Positive
# Spider-Man : Way Home : Doc Ock's Arms CGI , Practical Effects : strings . One coolest touches Sam Raimi ’ 2004 Spider-Man 2 Alfred Molina ’ Doc Ock used practical … https://t.co/Bnc9JN7EyG https://t.co/cZkbqazj7j ---- Neutral
# Though unconfirmed , new leaks revealed previously unknown villains gameplay improvements Marvel's Spider-Man 2 . https://t.co/7yvngnreaI https://t.co/rNGtqaZ0mf ---- Negative
# leaks possible pre-production 90 % sales new competitor https://t.co/LKR6K3OQLe ---- Neutral
# leaks possible pre-production 90 % sales new competitor https://t.co/LKR6K3OQLe ---- Neutral
# leaks possible pre-production 90 % sales new competitor https://t.co/LKR6K3OQLe ---- Neutral
# leaks possible pre-production 90 % sales new competitor https://t.co/LKR6K3OQLe ---- Neutral
# leaks possible pre-production 90 % sales new competitor https://t.co/LKR6K3OQLe ---- Neutral
# leaks possible pre-production 90 % sales new competitor https://t.co/LKR6K3OQLe ---- Neutral
# leaks possible pre-production 90 % sales new competitor https://t.co/LKR6K3OQLe ---- Neutral
# leaks possible pre-production 90 % sales new competitor https://t.co/LKR6K3OQLe ---- Neutral
# leaks possible pre-production 90 % sales new competitor https://t.co/LKR6K3OQLe ---- Neutral
# leaks possible pre-production 90 % sales new competitor https://t.co/LKR6K3OQLe ---- Neutral
# leaks possible pre-production 90 % sales new competitor https://t.co/LKR6K3OQLe ---- Neutral
# leaks possible pre-production 90 % sales new competitor https://t.co/LKR6K3OQLe ---- Neutral
# leaks possible pre-production 90 % sales new competitor https://t.co/LKR6K3OQLe ---- Neutral
# leaks possible pre-production 90 % sales new competitor https://t.co/LKR6K3OQLe ---- Neutral
# SPIDERMAN across spider verse https://t.co/RQGLxklYFM ---- Neutral
# SPIDERMAN across spider verse https://t.co/pO6uQmtlqn ---- Neutral
# Day 33 asking Insomniac please add Captain Universe suit Spider-Man 2 either Peter Miles https://t.co/xYmXQoCmaP ---- Neutral
# . called Alfred Molina " one favorite people I've ever worked . " fans strangers Molina , first appeared Tobey Maguire ’ . However , lot changed since . https://t.co/IdFiPHXrvD ---- Positive
# Oh man remember scene . https://t.co/546lsxJfdf ---- Neutral
# hello Terry today want present new suit Peter Parker fusion spidey CAP hope like approve ️ ️ ️ ️ https://t.co/eAm0W0njkD ---- Positive
# File find , 3 original pages Spidey triptych https://t.co/Fz7Uo4u4Qv ---- Neutral
# hello Aaron today want present new suit Peter Parker fusion spidey CAP hope like approve ️ ️ ️ ️ https://t.co/bslaAWAwns ---- Positive
# SPIDERMAN MOVIES RANKED https://t.co/VCyD2gCAKX https://t.co/2z5km8TNgk https://t.co/RJbSudDOOp ---- Neutral
# SPIDERMAN MOVIES RANKED https://t.co/6KscRxZn1P https://t.co/V6cHDiATxt ---- Neutral
# New details Marvel's Spider-Man 2 game leaked https://t.co/3MpiKZoVQD ---- Negative
# watched ( 2004 ) ---- Neutral
# Doctor Octopus , formerly Dr . Otto Gunther Octavius , archenemy Spider-Man . Sometimes referred Doc Ock short . forms Sinister Six fight Spider-Man . https://t.co/jgQIOeDQQM ---- Negative
# Hey starring & coming platform . films want get views comes ! ! ! ---- Neutral
# legend seen ’ Venoms voice game well . watching scare shit Child playing one favorite anti-hero ’ great . https://t.co/n5REv77cJr ---- Positive
# Hope guys forget homegirl Spider-Man 2 - one favorite spideys Miles doubt https://t.co/DM2z0w7oRC ---- Neutral
# Red , childhood . https://t.co/u0Uhv3YNP4 ---- Neutral
# hello shane today want present new suit Peter Parker fusion spidey CAP hope like approve ️ ️ ️ ️ https://t.co/muIuuWST2h ---- Positive
# hello shane today want present new suit Peter Parker fusion spidey CAP hope like approve ️ ️ ️ ️ https://t.co/H7XTQSLIy8 ---- Positive
# better look Advanced suit 2.0 love XD https://t.co/JVDIzV7gWq ---- Positive
# Day 13 SWAPTOBER SPIDER-MAN https://t.co/feLEPuLy5E ---- Neutral
# Hype 2023 https://t.co/GSZoVR1KUN ---- Neutral
# hello matt today want present new suit Peter Parker fusion spidey CAP hope like approve insomniac games ️ ️ ️ ️ https://t.co/3Pp4qtoO05 ---- Positive
# hello today want present new suit Peter Parker fusion spidey CAP hope like approve insomniac games ️ https://t.co/pA0FXsjkky ---- Positive
# ’ new comic book day ! Make sure grab issues DM ! Also , check awesome merchandise threadless store https://t.co/L1GfuYkzQo https://t.co/S0TJqjq17h ---- Positive
# saved train full people without help Iron man high tech gadgets , strongest Spider-Man ever Pure classic ! ! ! https://t.co/JbpINiMvZh https://t.co/NsSYCTepFZ ---- Positive
# Big rumored details PS5 game ! take place ? getting great reviews calls next season “ messed . ” Plus best hump day news ! https://t.co/XCLfmoieoG ---- Positive
# Day 32 asking Insomniac please add Captain Universe suit Spider-Man 2 either Peter Miles https://t.co/bnZfAB58DB ---- Neutral
# Still perfection ’ , AKA generation defining visual masterpiece https://t.co/nnmhLdQlSl ---- Positive
# Spider-Man 2 Players Could Get Choose Peter Parker Miles Morales According Rumors ! https://t.co/TQZpB3hDNq https://t.co/OIO356Qi6G ---- Neutral
# SABLE ENTERS CHAT : SPIDERMAN PS4 STREAM TONIGHT 11:30 PM https://t.co/oFpVqhdFm0 https://t.co/5Z5h509szg ---- Neutral
# hello david today want present new suit Peter Parker fusion spidey CAP hope like share insomniac games ️ ️ ️ ️ https://t.co/yckjxj4qvY ---- Positive
# hello Jordan today want present new suit Peter Parker fusion spidey CAP hope like share insomniac games ️ ️ ️ ️ https://t.co/aTab2Jxj7P ---- Positive
# Skylar Grey & Eminem - Last One Standing | Venom let Carnage ( Music Video ) https://t.co/pMGB0tuGMj ---- Neutral
# week talk need ( like ) , take break praise genius under-appreciated sense style . Check full episode wherever listen ! https://t.co/hFxnp7URiq ---- Positive
# ? ? Imagine favorite co-op ! also talk , tropes can't stand ! ! https://t.co/jq2mtofvFO ---- Positive
# hello hammers today want present new suit Peter Parker fusion spidey CAP hope like approve ️ ️ ️ ️ https://t.co/kmWemDgzpq ---- Positive
# hello roy today want present new suit Peter Parker fusion spidey CAP hope like approve ️ ️ ️ ️ https://t.co/DKxBSlxlND ---- Positive
# hello liam today want present new suit Peter Parker fusion spidey CAP hope like approve https://t.co/4GYrhk61s9 ---- Positive
# hello max today want present new suit Peter Parker fusion spidey CAP hope like approve ️ ️ ️ ️ https://t.co/HZSyUpbcJK ---- Positive
# Day 31 asking Insomniac please add Captain Universe suit Spider-Man 2 either Peter Miles https://t.co/NRZ1c2GTFw ---- Neutral
# nearly forgot one , said , MJ ? 🤭 2 https://t.co/YOTOeI6U7C ---- Positive
# Aunt May words strong 2 https://t.co/1pPN0WftCI ---- Positive
# Dashboard Confessional , Train Michael Bublee movie ’ ---- Neutral
# ’ know ’ soundtrack “ Ordinary ” still bop https://t.co/QbsqA6BYHx ---- Neutral
# one important question . know said would dark , gotta know . Spider - Man Quips ? Also thank making good memories amazing games ! ---- Positive
# “ Let slip away ! ! ! ” https://t.co/V3yxiBwsAK ---- Neutral
# thanks hanging . fun . love movie . ---- Positive
# Allways good see Normie https://t.co/3yB4fNOv2Y ---- Positive
# Epic night ! We're watching October 26 ! Two weeks ! https://t.co/Yqg59Owuhs ---- Neutral
