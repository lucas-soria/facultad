# %% [markdown]
# # Sistema de control de frenado de bicicleta
#
# Este sistema tiene como objetivo el control del freno de una bicicleta, este se presionará con una intensidad que va desde el 0 % al 100% dependiendo de la distancia de la bicicleta al un semáforo y su velocidad actual.

# %%
# %matplotlib notebook
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
import matplotlib.pyplot as plt

# %% [markdown]
# ## Velocidad
#
# La velocidad se clasificará de la siguiente manera:
#  - <b>Detenida: </b> menos de 5 km/h
#  - <b>Lenta: </b> 0 a 20 km/h
#  - <b>Rápida: </b> 10 a 50 km/h
#  - <b>Muy rápida: </b> 30 a 50 km/h

# %%
speed = ctrl.Antecedent(np.arange(0, 60, 1), 'speed')
speed['stopped'] = fuzz.trapmf(speed.universe, [0, 0, 5, 5])
speed['slow'] = fuzz.trimf(speed.universe, [0, 10, 20])
speed['fast'] = fuzz.trimf(speed.universe, [10, 30, 50])
speed['vfast'] = fuzz.trapmf(speed.universe, [30, 50, 60, 60])
speed['slow'].view()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Distancia
#
# La distancia al semáforo se clasificará de la siguiente manera:
#  - <b>Encima: </b> menos de 5 m
#  - <b>Cerca: </b> 5 m a 25 m
#  - <b>Lejos: </b> 20 m a 40 m
#  - <b>Muy Lejos: </b> 35 m a 50 m

# %%
distance = ctrl.Antecedent(np.arange(0, 60, 1), 'distance')
distance['inplace'] = fuzz.trapmf(distance.universe, [0, 0, 5, 5])
distance['vclose'] = fuzz.trimf(distance.universe, [0, 5, 10])
distance['close'] = fuzz.trimf(distance.universe, [5, 15, 25])
distance['far'] = fuzz.trimf(distance.universe, [20, 30, 40])
distance['vfar'] = fuzz.trapmf(distance.universe, [35, 50, 60, 60])
distance.view()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Presión
#
# La presión ejercida sobre el freno se clasificará de la siguiente manera:
#  - <b>Nada: </b> 0%
#  - <b>Ligera: </b> 0% a 30%
#  - <b>Media: </b> 20% a 80%
#  - <b>Fuerte: </b> 50% a  80%

# %%
pressure = ctrl.Consequent(np.arange(0, 100, 1), 'pressure')
pressure['none'] = fuzz.trimf(pressure.universe, [0, 0, 0])
pressure['light'] = fuzz.trimf(pressure.universe, [0, 15, 30])
pressure['medium'] = fuzz.trimf(pressure.universe, [20, 50, 80])
pressure['strong'] = fuzz.trapmf(pressure.universe, [50, 80, 100, 100])
pressure.view()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
method = "bisector"
#centroid
#bisector
#mom
#som
#lom
pressure.defuzzify_method = method

# %% [markdown]
# ## Reglas
#
# Las siguientes reglas definiran que tipo de presión es la recomendada para cada situación.
#
# <table style="float:left; font-size:15px">
#     <tr>
#         <th></th>
#         <th>Detenida</th>
#         <th>Lenta</th>
#         <th>Rápida</th>
#         <th>Muy Rápida</th>
#     </tr>
#     <tr>
#         <th>Encima</th>
#         <td>Nada</td>
#         <td>Media</td>
#         <td>Fuerte</td>
#         <td>Fuerte</td>
#     </tr>
#     <tr>
#         <th>Muy Cerca</th>
#         <td>Nada</td>
#         <td>Ligera</td>
#         <td>Fuerte</td>
#         <td>Fuerte</td>
#     </tr>
#     <tr>
#         <th>Cerca</th>
#         <td>Nada</td>
#         <td>Ligera</td>
#         <td>Fuerte</td>
#         <td>Fuerte</td>
#     </tr>
#     <tr>
#         <th>Lejos</th>
#         <td>Nada</td>
#         <td>Nada</td>
#         <td>Media</td>
#         <td>Media</td>
#     </tr>
#     <tr>
#         <th>Muy Lejos</th>
#         <td>Nada</td>
#         <td>Nada</td>
#         <td>Ligera</td>
#         <td>Ligera</td>
#     </tr>
# </table>

# %%
rules = []
rules.append(ctrl.Rule( speed['stopped']                          ,pressure['none']))
rules.append(ctrl.Rule( speed['slow']       & distance['far']     ,pressure['none']))
rules.append(ctrl.Rule( speed['slow']       & distance['vfar']    ,pressure['none']))
rules.append(ctrl.Rule( speed['slow']       & distance['close']   ,pressure['light']))
rules.append(ctrl.Rule( speed['slow']       & distance['vclose']  ,pressure['light']))
rules.append(ctrl.Rule( distance['vfar']    & speed['fast']       ,pressure['light']))
rules.append(ctrl.Rule( distance['vfar']    & speed['vfast']      ,pressure['light']))
rules.append(ctrl.Rule( speed['slow']       & distance['inplace'] ,pressure['medium']))
rules.append(ctrl.Rule( distance['far']     & speed['fast']       ,pressure['medium']))
rules.append(ctrl.Rule( distance['far']     & speed['vfast']      ,pressure['medium']))
rules.append(ctrl.Rule( distance['inplace'] & speed['fast']       ,pressure['strong']))
rules.append(ctrl.Rule( distance['inplace'] & speed['vfast']      ,pressure['strong']))
rules.append(ctrl.Rule( distance['vclose']  & speed['fast']       ,pressure['strong']))
rules.append(ctrl.Rule( distance['vclose']  & speed['vfast']      ,pressure['strong']))
rules.append(ctrl.Rule( distance['close']   & speed['fast']       ,pressure['strong']))
rules.append(ctrl.Rule( distance['close']   & speed['vfast']      ,pressure['strong']))

# %%
breaking_ctrl = ctrl.ControlSystem(rules)
breaking = ctrl.ControlSystemSimulation(breaking_ctrl)

# %%
breaking.input['speed'] = 20
breaking.input['distance'] = 23

# %%
breaking.compute()

# %%
breaking.print_state()
# Out:
# =============
#  Antecedents
# =============
# Antecedent: speed                   = 20
#   - stopped                         : 0.0
#   - slow                            : 0.0
#   - fast                            : 0.5
#   - vfast                           : 0.0
# Antecedent: distance                = 23
#   - inplace                         : 0.0
#   - vclose                          : 0.0
#   - close                           : 0.2
#   - far                             : 0.3
#   - vfar                            : 0.0
#
# =======
#  Rules
# =======
# RULE #0:
#   IF speed[stopped] THEN pressure[none]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - speed[stopped]                                         : 0.0
#                                             speed[stopped] = 0.0
#   Activation (THEN-clause):
#                                             pressure[none] : 0.0
#
# RULE #1:
#   IF speed[slow] AND distance[far] THEN pressure[none]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - speed[slow]                                            : 0.0
#   - distance[far]                                          : 0.3
#                              speed[slow] AND distance[far] = 0.0
#   Activation (THEN-clause):
#                                             pressure[none] : 0.0
#
# RULE #2:
#   IF speed[slow] AND distance[vfar] THEN pressure[none]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - speed[slow]                                            : 0.0
#   - distance[vfar]                                         : 0.0
#                             speed[slow] AND distance[vfar] = 0.0
#   Activation (THEN-clause):
#                                             pressure[none] : 0.0
#
# RULE #3:
#   IF speed[slow] AND distance[close] THEN pressure[light]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - speed[slow]                                            : 0.0
#   - distance[close]                                        : 0.2
#                            speed[slow] AND distance[close] = 0.0
#   Activation (THEN-clause):
#                                            pressure[light] : 0.0
#
# RULE #4:
#   IF speed[slow] AND distance[vclose] THEN pressure[light]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - speed[slow]                                            : 0.0
#   - distance[vclose]                                       : 0.0
#                           speed[slow] AND distance[vclose] = 0.0
#   Activation (THEN-clause):
#                                            pressure[light] : 0.0
#
# RULE #5:
#   IF distance[vfar] AND speed[fast] THEN pressure[light]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - distance[vfar]                                         : 0.0
#   - speed[fast]                                            : 0.5
#                             distance[vfar] AND speed[fast] = 0.0
#   Activation (THEN-clause):
#                                            pressure[light] : 0.0
#
# RULE #6:
#   IF distance[vfar] AND speed[vfast] THEN pressure[light]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - distance[vfar]                                         : 0.0
#   - speed[vfast]                                           : 0.0
#                            distance[vfar] AND speed[vfast] = 0.0
#   Activation (THEN-clause):
#                                            pressure[light] : 0.0
#
# RULE #7:
#   IF speed[slow] AND distance[inplace] THEN pressure[medium]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - speed[slow]                                            : 0.0
#   - distance[inplace]                                      : 0.0
#                          speed[slow] AND distance[inplace] = 0.0
#   Activation (THEN-clause):
#                                           pressure[medium] : 0.0
#
# RULE #8:
#   IF distance[far] AND speed[fast] THEN pressure[medium]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - distance[far]                                          : 0.3
#   - speed[fast]                                            : 0.5
#                              distance[far] AND speed[fast] = 0.3
#   Activation (THEN-clause):
#                                           pressure[medium] : 0.3
#
# RULE #9:
#   IF distance[far] AND speed[vfast] THEN pressure[medium]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - distance[far]                                          : 0.3
#   - speed[vfast]                                           : 0.0
#                             distance[far] AND speed[vfast] = 0.0
#   Activation (THEN-clause):
#                                           pressure[medium] : 0.0
#
# RULE #10:
#   IF distance[inplace] AND speed[fast] THEN pressure[strong]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - distance[inplace]                                      : 0.0
#   - speed[fast]                                            : 0.5
#                          distance[inplace] AND speed[fast] = 0.0
#   Activation (THEN-clause):
#                                           pressure[strong] : 0.0
#
# RULE #11:
#   IF distance[inplace] AND speed[vfast] THEN pressure[strong]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - distance[inplace]                                      : 0.0
#   - speed[vfast]                                           : 0.0
#                         distance[inplace] AND speed[vfast] = 0.0
#   Activation (THEN-clause):
#                                           pressure[strong] : 0.0
#
# RULE #12:
#   IF distance[vclose] AND speed[fast] THEN pressure[strong]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - distance[vclose]                                       : 0.0
#   - speed[fast]                                            : 0.5
#                           distance[vclose] AND speed[fast] = 0.0
#   Activation (THEN-clause):
#                                           pressure[strong] : 0.0
#
# RULE #13:
#   IF distance[vclose] AND speed[vfast] THEN pressure[strong]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - distance[vclose]                                       : 0.0
#   - speed[vfast]                                           : 0.0
#                          distance[vclose] AND speed[vfast] = 0.0
#   Activation (THEN-clause):
#                                           pressure[strong] : 0.0
#
# RULE #14:
#   IF distance[close] AND speed[fast] THEN pressure[strong]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - distance[close]                                        : 0.2
#   - speed[fast]                                            : 0.5
#                            distance[close] AND speed[fast] = 0.2
#   Activation (THEN-clause):
#                                           pressure[strong] : 0.2
#
# RULE #15:
#   IF distance[close] AND speed[vfast] THEN pressure[strong]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
#
#   Aggregation (IF-clause):
#   - distance[close]                                        : 0.2
#   - speed[vfast]                                           : 0.0
#                           distance[close] AND speed[vfast] = 0.0
#   Activation (THEN-clause):
#                                           pressure[strong] : 0.0
#
#
# ==============================
#  Intermediaries and Conquests
# ==============================
# Consequent: pressure                 = 57.33333333333332
#   none:
#     Accumulate using accumulation_max : 0.0
#   light:
#     Accumulate using accumulation_max : 0.0
#   medium:
#     Accumulate using accumulation_max : 0.3
#   strong:
#     Accumulate using accumulation_max : 0.2

# %%
print("Resultado: "+str(breaking.output['pressure']))
# Out:
# Resultado: 57.33333333333332

# %%
pressure.view(sim=breaking)
#plt.savefig('/tmp/'+method+'png')
# Out:
# <img src="data:image/png;base64,..." width="640">
